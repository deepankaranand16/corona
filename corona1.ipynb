# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
pd.read_excel('corona1.xlsx')
# Out:
#                  Name  total cases  total death  total recovered  \
# 0               World    697964044      6939362      669545680.0
# 1                 USA    109358792      1182276      107297444.0
# 2               India     45001536       533295      908765777.0
# 3              France     40138560       167642       39970918.0
# 4             Germany     38608185       177637       38240600.0
# ..                ...          ...          ...              ...
# 227  Diamond Princess          712           13            699.0
# 228           Tokelau           80          651             98.0
# 229      Vatican City           29            6             29.0
# 230    Western Sahara           10            4              9.0
# 231        MS Zaandam            9            2              7.0
#
#      active cases  serious crital  toal cases/1M  total death/1M  \
# 0        21479002         37873.0          89542           890.3
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('corona1.xlsx')

# %%
df
# Out:
#                  Name  total cases  total death  total recovered  \
# 0               World    697964044      6939362      669545680.0
# 1                 USA    109358792      1182276      107297444.0
# 2               India     45001536       533295      908765777.0
# 3              France     40138560       167642       39970918.0
# 4             Germany     38608185       177637       38240600.0
# ..                ...          ...          ...              ...
# 227  Diamond Princess          712           13            699.0
# 228           Tokelau           80          651             98.0
# 229      Vatican City           29            6             29.0
# 230    Western Sahara           10            4              9.0
# 231        MS Zaandam            9            2              7.0
#
#      active cases  serious crital  toal cases/1M  total death/1M  \
# 0        21479002         37873.0          89542           890.3
# ...

# %%
df.head()
# Out:
#       Name  total cases  total death  total recovered  active cases  \
# 0    World    697964044      6939362      669545680.0      21479002
# 1      USA    109358792      1182276      107297444.0        879072
# 2    India     45001536       533295      908765777.0            54
# 3   France     40138560       167642       39970918.0             0
# 4  Germany     38608185       177637       38240600.0        189948
#
#    serious crital  toal cases/1M  total death/1M    total test   test/1M
# 0         37873.0          89542           890.3  9.846513e+09  32658465
# 1          1276.0         326634          3531.0  1.186432e+09   3543648
# 2            54.0          31992           379.0  9.307980e+08    661721
# 3           869.0         612013          2556.0  2.714902e+08   4139547
# 4             5.0         460259          2118.0  1.223324e+08   1458359

# %%
df.columns
# Out:
# Index(['Name', 'total cases', 'total death', 'total recovered', 'active cases',
#        'serious crital', 'toal cases/1M', 'total death/1M', 'total test',
#        'test/1M'],
#       dtype='object')

# %%
df.shape
# Out:
# (232, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232 entries, 0 to 231
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             232 non-null    object
#  1   total cases      232 non-null    int64
#  2   total death      232 non-null    int64
#  3   total recovered  231 non-null    float64
#  4   active cases     232 non-null    int64
#  5   serious crital   231 non-null    float64
#  6   toal cases/1M    232 non-null    int64
#  7   total death/1M   232 non-null    float64
#  8   total test       231 non-null    float64
#  9   test/1M          232 non-null    int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 18.3+ KB

# %%
df.isna().sum()
# Out:
# Name               0
# total cases        0
# total death        0
# total recovered    1
# active cases       0
# serious crital     1
# toal cases/1M      0
# total death/1M     0
# total test         1
# test/1M            0
# dtype: int64

# %%
df.nunique()
# Out:
# Name               232
# total cases        232
# total death        216
# total recovered    231
# active cases       190
# serious crital      81
# toal cases/1M      231
# total death/1M     220
# total test         228
# test/1M            232
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3

# %%
df.nunique().plot.bar(figsize=(30,20))
plt.xlabel('variable')
plt.ylabel('Number of unique value')
plt.title('Number of missing')
# Out:
# Text(0.5, 1.0, 'Number of missing')

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, total cases, total death, total recovered, active cases, serious crital, toal cases/1M, total death/1M, total test, test/1M]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for feature in df.columns:
  print(df[feature].value_counts())
# Out:
# Name
# World                 1
# Mayotte               1
# Mauritania            1
# Bhutan                1
# Syria                 1
#                      ..
# Dominican Republic    1
# Kuwait                1
# Cyprus                1
# Myanmar               1
# MS Zaandam            1
# Name: count, Length: 232, dtype: int64
# total cases
# 697964044    1
# 42027        1
# 63774        1
# 62697        1
# 57743        1
#             ..
# 670627       1
# 666501       1
# 660854       1
# 641368       1
# 9            1
# Name: count, Length: 232, dtype: int64
# total death
# 2        3
# 21       2
# 6        2
# 113      2
# 138      2
#         ..
# 6425     1
# 9646     1
# 10361    1
# 20028    1
# 4        1
# Name: count, Length: 216, dtype: int64
# total recovered
# 669545680.0    1
# 58947.0        1
# 61564.0        1
# 54578.0        1
# 53569.0        1
#               ..
# 660237.0       1
# 659490.0       1
# 619922.0       1
# 75365112.0     1
# ...

# %%
df.columns
# Out:
# Index(['Name', 'total cases', 'total death', 'total recovered', 'active cases',
#        'serious crital', 'toal cases/1M', 'total death/1M', 'total test',
#        'test/1M'],
#       dtype='object')

# %%
df['Name'].value_counts()
# Out:
# Name
# World                 1
# Mayotte               1
# Mauritania            1
# Bhutan                1
# Syria                 1
#                      ..
# Dominican Republic    1
# Kuwait                1
# Cyprus                1
# Myanmar               1
# MS Zaandam            1
# Name: count, Length: 232, dtype: int64

# %%
sns.distplot(df['total cases'])
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_10676\2241155686.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total cases'])
# <Axes: xlabel='total cases', ylabel='Density'>

# %%
sns.countplot(df['total death'])
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(18,15))
gender = pd.crosstab(df['Name'],df['total recovered'])
gender.plot(kind='bar')
# Out:
# <Axes: xlabel='Name'>

# %%
df.describe()
# Out:
#         total cases   total death  total recovered  active cases  \
# count  2.320000e+02  2.320000e+02     2.310000e+02  2.320000e+02
# mean   6.016931e+06  5.985897e+04     1.142686e+07  1.814392e+05
# std    4.667727e+07  4.660681e+05     7.490935e+07  1.506064e+06
# min    9.000000e+00  1.000000e+00     2.000000e+00  0.000000e+00
# 25%    2.526000e+04  1.927500e+02     2.691350e+04  5.400000e+01
# 50%    2.080915e+05  2.066500e+03     3.370680e+05  9.135000e+02
# 75%    1.348320e+06  1.436500e+04     2.074016e+06  9.412250e+03
# max    6.979640e+08  6.939362e+06     9.087658e+08  2.147900e+07
#
#        serious crital  toal cases/1M  total death/1M    total test  \
# count      231.000000     232.000000      232.000000  2.310000e+02
# mean       239.077922  198356.745690     1340.380603  7.316074e+07
# std       2508.220357  201514.331297     1629.573567  6.560159e+08
# min          0.000000     347.000000        2.000000  5.400000e+01
# ...

# %%
df.describe().T
# Out:
#                  count          mean           std    min        25%  \
# total cases      232.0  6.016931e+06  4.667727e+07    9.0   25260.00
# total death      232.0  5.985897e+04  4.660681e+05    1.0     192.75
# total recovered  231.0  1.142686e+07  7.490935e+07    2.0   26913.50
# active cases     232.0  1.814392e+05  1.506064e+06    0.0      54.00
# serious crital   231.0  2.390779e+02  2.508220e+03    0.0       4.50
# toal cases/1M    232.0  1.983567e+05  2.015143e+05  347.0   18648.75
# total death/1M   232.0  1.340381e+03  1.629574e+03    2.0     177.75
# total test       231.0  7.316074e+07  6.560159e+08   54.0  346778.50
# test/1M          232.0  2.512168e+06  5.809840e+06  511.0  168841.00
#
#                        50%          75%           max
# total cases       208091.5   1348319.75  6.979640e+08
# total death         2066.5     14365.00  6.939362e+06
# total recovered   337068.0   2074015.50  9.087658e+08
# active cases         913.5      9412.25  2.147900e+07
# ...

# %%
sns.pairplot(df,diag_kind='kde')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(30,20))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Name'] =le.fit_transform(df['Name'])

# %%
df['total cases'] =le.fit_transform(df['total cases'])

# %%
df
# Out:
#      Name  total cases  total death  total recovered  active cases  \
# 0     228          231      6939362      669545680.0      21479002
# 1     217          230      1182276      107297444.0        879072
# 2      94          229       533295      908765777.0            54
# 3      72          228       167642       39970918.0             0
# 4      78          227       177637       38240600.0        189948
# ..    ...          ...          ...              ...           ...
# 227    56            4           13            699.0             0
# 228   208            3          651             98.0            80
# 229   223            2            6             29.0             0
# 230   227            1            4              9.0             0
# 231   120            0            2              7.0             0
#
#      serious crital  toal cases/1M  total death/1M    total test   test/1M
# 0           37873.0          89542           890.3  9.846513e+09  32658465
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X= df.drop(['corona1'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 X= df.drop(['corona1'],axis=1)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...
